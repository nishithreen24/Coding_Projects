# %%
import numpy as np
import matplotlib.pyplot as plt
def plotline(slope_angle, intercept, start, end):
    c = intercept
    if (slope_angle==(np.pi/2)):
        X = np.linspace(start, end, 100)
        Y = X*0+c
        plt.plot(Y, X)
    else:
        X = np.linspace(start, end, 100)
        m = np.tan(slope_angle)
        Y = (X*m)+c
        plt.plot(X, Y)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.grid()
def rotatem(m, theta):
    if(m==np.tan((np.pi/2))):
        return(-1/np.tan(theta))
    else:
        return(((m*np.cos(theta))+np.sin(theta))/(np.cos(theta)-(m*np.sin(theta))))
def rotatec(m, c, theta):
    if(m==np.tan((np.pi/2))):
        return(c/np.sin(theta))
    else:
        return(c/(np.cos(theta)-(m*np.sin(theta))))
def plotm(m, c, s, e):
    if (m==np.tan((np.pi/2))):
        X = np.linspace(s, e, 100)
        Y = X*0+c
        plt.plot(Y, X)
    else:
        X = np.linspace(s, e, 100)
        Y = (X*m)+c
        plt.plot(X, Y)
#def rotatel(l, theta):
    #if(l==0):
        #return 0
    #else:
        #return l*
sx = 0
sy = -1
ex = 1
ey = 1
m1 = 0
m2 = 0
m3 = np.tan((np.pi/2))
m4 = np.tan((np.pi/2))
c1 = -1
c2 = 1
c3 = 0
c4 = 1
plotm(m1, c1, sx, ex)
plotm(m2, c2, sx, ex)
plotm(m3, c3, sy, ey)
plotm(m4, c4, sy, ey)
rotation = (np.pi)/4
plt.show()
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.grid()
l1 = 1*np.cos(rotation)
l2 = 2*np.cos(rotation)
l3 = 0*np.cos(rotation)
l4 = -1*np.cos(rotation)
m1n = rotatem(m1, rotation)
c1n = rotatec(m1, c1, rotation)
plotm(m1n, c1n, l1, l2)
m2n = rotatem(m2, rotation)
c2n = rotatec(m2, c2, rotation)
plotm(m2n, c2n, l3, l4)
m3n = rotatem(m3, rotation)
c3n = rotatec(m3, c3, rotation)
plotm(m3n, c3n, l4, l1)
m4n = rotatem(m4, rotation)
c4n = rotatec(m4, c4, rotation)
plotm(m4n, c4n, l2, l3)
