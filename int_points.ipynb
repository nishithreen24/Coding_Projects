# %%
import matplotlib.pyplot as plt
import numpy as np
X = np.arange(-10, 10, 1)
Y1 = X
Y2 = -1*X
plt.grid()
plt.plot(X, Y1)
plt.plot(X, Y2)
for x in X:
    if(Y1[x]==Y2[x]):
        print(X[x], ",", Y1[x])
        break
# Out:
# 0 , 0
