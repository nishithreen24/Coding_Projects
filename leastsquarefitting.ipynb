# %%
import matplotlib.pyplot as plt
import numpy as np
class lsf:
#for k in range(0, 3):
    #if(k==0):
        #x = [1, 1.5, 2, 2.5, 3, 3.5, 4]
        #y = [25, 31, 27, 28, 36, 35, 32]
    #elif(k==1):
        #x = [1, -1, 1]
        #y = [2, 1, 3]
    #elif(k==2):
        #x = [0, 30, 70, 100]
        #y = [0.94, 1.05, 1.17, 1.28]
    x = [2.095, 2.642, 3.004, 3.354, 4.138, 6.106]
    y = [1.643, 1.646, 1.647, 1.650, 1.671, 1.680]
    sigx = 0
    sigy = 0
    sigxy = 0
    sigx2 = 0
    n = len(x)
    for i in range(n):
        sigx = sigx + x[i]
        sigy = sigy + y[i]
        sigxy = sigxy + x[i]*y[i]
        sigx2 = sigx2 + x[i]*x[i]
    a = (n*sigxy-sigx*sigy)/(n*sigx2-sigx*sigx)
    b = sigy/n-a*sigx/n
    print("a =", a)
    print("b =", b)
    #Y = []
    #for i in range(n):
        #Y.append(a*x[i]+b)
    plt.plot(x, y, 'ro')
    #plt.plot(x, Y)
    #plt.xlim(-1, 7)
    #plt.ylim(0, 2)
    print(a*6.106+b)
    X = np.linspace(-5, 10)
    Y = a*X+b
    plt.plot(X, Y)
# Out:
# a = 0.010263475226446793
# b = 1.6196646170238085
# 1.6823333967564926
