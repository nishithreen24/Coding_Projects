# %%
import math
import matplotlib.pyplot as plt
def f1(x, y):
    return(((x**3)*math.exp(-2*x))-(2*y))
def f2(x, y):
    return(x-3)
x = -1
y = 1.847
h = 0.1
X = []
Y = []
for i in range(0, 100):
    y = y + f1(x, y)*h # Euler Methdd
    #y = y + f1(x+h/2, y+f1(x, y)*h/2)*h Euler Method with half step
    #y = y + (f1(x, y) + f1(x+h, y+f1(x, y)*h))*h/2 Modified Euler Method
    x = x + h
    Y.append(y)
    X.append(x)
    i = i + 1
    print("x", i, " = ", x, " y", i, " = ", y)
plt.plot(X, Y)
# Out:
# x 1  =  -0.9  y 1  =  0.7386943901069347
# x 2  =  -0.8  y 2  =  0.14993621192984385
# x 3  =  -0.7000000000000001  y 3  =  -0.13364629058515481
# x 4  =  -0.6000000000000001  y 4  =  -0.24601039133089625
# x 5  =  -0.5000000000000001  y 5  =  -0.2685228385958265
# x 6  =  -0.40000000000000013  y 6  =  -0.24879679373239927
# x 7  =  -0.30000000000000016  y 7  =  -0.21328089692827124
# x 8  =  -0.20000000000000015  y 8  =  -0.17554443830367136
# x 9  =  -0.10000000000000014  y 9  =  -0.1416290104010501
# x 10  =  -1.3877787807814457e-16  y 10  =  -0.11342534859665611
# x 11  =  0.09999999999999987  y 11  =  -0.09074027887732489
# x 12  =  0.19999999999999987  y 12  =  -0.07251035002655211
# x 13  =  0.2999999999999999  y 13  =  -0.05747202398441317
# x 14  =  0.3999999999999999  y 14  =  -0.04449582777007667
# x 15  =  0.4999999999999999  y 15  =  -0.03272095684571112
# x 16  =  0.5999999999999999  y 16  =  -0.021578272461925868
# ...
