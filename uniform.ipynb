# %%
import numpy as np
import matplotlib.pyplot as plt
s = np.random.uniform(-1,0,1000)
count, x, ignored = plt.hist(s, 15, density=True)
plt.plot(x, np.ones_like(x), linewidth=2, color='r')
plt.show()
