# %%
import math
import matplotlib.pyplot as plt
def f1(x, y):
    return(((x**3)*math.exp(-2*x))-(2*y))
def f2(x, y):
    return(x-3)
x = -1
y = 1.847
h = 0.1
X = []
Y = []
for i in range(0, 100):
    y = y + f1(x+h/2, y+f1(x, y)*h/2)*h
    x = x + h
    Y.append(y)
    X.append(x)
    i = i + 1
    print("x", i, " = ", x, " y", i, " = ", y)
plt.plot(X, Y)
# Out:
# x 1  =  -0.9  y 1  =  1.0151986862443878
# x 2  =  -0.8  y 2  =  0.5403960585415217
# x 3  =  -0.7000000000000001  y 3  =  0.2794130363620637
# x 4  =  -0.6000000000000001  y 4  =  0.142259965968676
# x 5  =  -0.5000000000000001  y 5  =  0.07384281242401645
# x 6  =  -0.40000000000000013  y 6  =  0.041535825122849576
# x 7  =  -0.30000000000000016  y 7  =  0.026849758061692153
# x 8  =  -0.20000000000000015  y 8  =  0.01993264670122405
# x 9  =  -0.10000000000000014  y 9  =  0.01600853892325812
# x 10  =  -1.3877787807814457e-16  y 10  =  0.013125401308177314
# x 11  =  0.09999999999999987  y 11  =  0.010774139540430846
# x 12  =  0.19999999999999987  y 12  =  0.009076633265102593
# x 13  =  0.2999999999999999  y 13  =  0.008336917829502265
# x 14  =  0.3999999999999999  y 14  =  0.008817202968452136
# x 15  =  0.4999999999999999  y 15  =  0.010647401921481938
# x 16  =  0.5999999999999999  y 16  =  0.013809162929177684
# x 17  =  0.6999999999999998  y 17  =  0.018157338470391915
# ...
