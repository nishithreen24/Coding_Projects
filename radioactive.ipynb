# %%
import math
import matplotlib.pyplot as plt
def func(x):
    l = x
    def f(t, N):
        return(-1*l*N)
    def fa(t):
        return(N0*math.exp(-1*l*t))
    t = 0
    N0 = 1000
    N = N0
    h = 1
    T = []
    n = []
    Na = N0
    Nm = N0
    na = []
    nm = []
    for i in range(0,40):
        N = N + f(t, N)*h
        Nm = Nm + f(t+h/2, Nm+f(t, Nm)*h/2)*h
        #Nm = Nm + (f(t, Nm)+f(t+h, Nm+f(t, Nm)*h))*h/2
        t = t + h
        Na = fa(t)
        T.append(t)
        n.append(N)
        na.append(Na)
        nm.append(Nm)
        i = i + 1
        print("t", i, " = ", t, " N", i, " = ", N," midpoint N = ", Nm ," analytic N = ", Na)
    plt.plot(T, nm)
    plt.plot(T, na)
    plt.plot(T, n)
    plt.legend(['Midpoint', 'Analytical', 'Euler'])
func(0.1)
func(0.075)
func(0.05)
# Out:
# t 1  =  1  N 1  =  900.0  midpoint N =  905.0  analytic N =  904.8374180359596
# t 2  =  2  N 2  =  810.0  midpoint N =  819.025  analytic N =  818.7307530779818
# t 3  =  3  N 3  =  729.0  midpoint N =  741.217625  analytic N =  740.8182206817179
# t 4  =  4  N 4  =  656.1  midpoint N =  670.801950625  analytic N =  670.3200460356393
# t 5  =  5  N 5  =  590.49  midpoint N =  607.0757653156251  analytic N =  606.5306597126335
# t 6  =  6  N 6  =  531.441  midpoint N =  549.4035676106407  analytic N =  548.8116360940264
# t 7  =  7  N 7  =  478.29690000000005  midpoint N =  497.21022868762986  analytic N =  496.58530379140944
# t 8  =  8  N 8  =  430.46721  midpoint N =  449.975256962305  analytic N =  449.3289641172216
# t 9  =  9  N 9  =  387.42048900000003  midpoint N =  407.22760755088603  analytic N =  406.5696597405991
# t 10  =  10  N 10  =  348.67844010000005  midpoint N =  368.5409848335519  analytic N =  367.87944117144235
# ...
